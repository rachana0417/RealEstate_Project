# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load cleaned dataset
df = pd.read_csv("../data/cleaned_data.csv")

df.head()
# Out:
#    ID  State  City  Locality  Property_Type  BHK  Size_in_SqFt  \
# 0   1      7    38       427              0    1          4740
# 1   2      3    27       373              1    3          2364
# 2   3      5    18       473              0    2          3642
# 3   4      6    14       253              1    2          2741
# 4   5      6    11       343              2    4          4823
#
#    Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  Nearby_Hospitals  \
# 0          489.76    10332.489451        1990  ...                 3
# 1          195.52     8270.727580        2008  ...                 1
# 2          183.79     5046.403075        1997  ...                 8
# 3          300.29    10955.490697        1991  ...                 7
# 4          182.90     3792.245490        2002  ...                 9
#
#    Public_Transport_Accessibility  Parking_Space  Security  \
# 0                            High             No         0
# 1                             Low             No         1
# 2                             Low            Yes         0
# 3                            High            Yes         1
# 4                             Low             No         1
#
#                                   Amenities  Facing Owner_Type  \
# 0  Playground, Gym, Garden, Pool, Clubhouse       3          2
# 1  Playground, Clubhouse, Pool, Gym, Garden       1          1
# 2          Clubhouse, Pool, Playground, Gym       2          0
# 3  Playground, Clubhouse, Gym, Pool, Garden       1          1
# 4  Playground, Garden, Gym, Pool, Clubhouse       0          1
#
#   Availability_Status  Amenity_Count Good_Investment
# 0                   0              5               0
# 1                   1              5               1
# 2                   0              4               1
# 3                   0              5               0
# 4                   0              5               1
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["Price_in_Lakhs"], kde=True, color='blue')
plt.title("Distribution of Property Prices (Lakhs)")
plt.xlabel("Price in Lakhs")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["Price_per_SqFt"], kde=True, color='green')
plt.title("Distribution of Price per SqFt")
plt.xlabel("Price per SqFt")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["Size_in_SqFt"], y=df["Price_in_Lakhs"], alpha=0.5)
plt.title("Relationship Between Size (SqFt) and Price (Lakhs)")
plt.xlabel("Size (SqFt)")
plt.ylabel("Price (Lakhs)")
plt.show()

# %%
plt.figure(figsize=(12,8))

# select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

sns.heatmap(numeric_df.corr(), annot=False, cmap="coolwarm")
plt.title("Correlation Heatmap of Numerical Features")
plt.show()
